# %% [markdown]
# # Orbit
# ## 1. Setup
# ### 1.1 Config

# %%
# MLflow model path
model_path = "model"

# prediction config for pyfunc flavor
pyfunc_predict_conf = {
        "decompose": True,
        "seed": 43,
}

# %% [markdown]
# ### 1.2 Imports

# %%
import mlflow
import mlflow_flavors
from mlflow.models import infer_signature
from orbit.models import DLT
from orbit.utils.dataset import load_iclaims
import pandas as pd

# %% [markdown]
# ### 1.3 Load sample data

# %%
df = load_iclaims()

# train-test split
test_size = 52
train_df = df[:-test_size]
test_df = df[-test_size:]

test_df.head()
# Out:
#           week     claims  trend.unemploy  trend.filling  trend.job     sp500  \
# 391 2017-07-02  12.440694        0.219882       0.104405  -0.079668  0.332886
# 392 2017-07-09  12.557887        0.252143       0.032946   0.029532  0.346844
# 393 2017-07-16  12.459796        0.186546       0.069313  -0.005560  0.352226
# 394 2017-07-23  12.303449        0.169451       0.032946   0.029532  0.352048
# 395 2017-07-30  12.199934        0.186546       0.051295   0.052260  0.353959
#
#           vix
# 391 -0.359894
# 392 -0.522570
# 393 -0.538469
# 394 -0.443742
# 395 -0.469334

# %% [markdown]
# ## 2. Example usage of native `orbit` flavor and `pyfunc` flavor

# %% [markdown]
# ### 2.1 Train and save model

# %%
with mlflow.start_run():

    dlt = DLT(
        response_col="claims",
        date_col="week",
        regressor_col=["trend.unemploy", "trend.filling", "trend.job"],
        seasonality=52,
    )
    dlt.fit(df=train_df)
    dlt.pyfunc_predict_conf = pyfunc_predict_conf

    mlflow_flavors.orbit.save_model(dlt, model_path)
# Out:
# INFO:orbit:Sampling (PyStan) with chains: 4, cores: 8, temperature: 1.000, warmups (per chain): 225 and samples(per chain): 25.
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# 2023/01/06 13:39:23 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: model/model.pkl, flavor: orbit), fall back to return ['orbit==1.1.3']. Set logging level to DEBUG to see the full traceback.
# /home/benjamin/PycharmProjects/mlflow_flavors/.venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# ### 2.2 Load model
# #### 2.2.1 Native orbit flavor

# %%
loaded_model = mlflow_flavors.orbit.load_model(model_path)

# %% [markdown]
# #### 2.2.1 Pyfunc flavor

# %%
loaded_pyfunc = mlflow_flavors.orbit.pyfunc.load_model(model_path)

# %% [markdown]
# ### 2.3 Generate predictions
# #### 2.3.1 Native orbit flavor

# %%
loaded_model.predict(test_df, decompose=True, seed=43).head()
# Out:
#         week  prediction_5  prediction  prediction_95    trend_5      trend  \
# 0 2017-07-02     12.329969   12.415831      12.505553  12.249114  12.337002
# 1 2017-07-09     12.426513   12.534631      12.623807  12.234586  12.345293
# 2 2017-07-16     12.299631   12.376752      12.470228  12.246894  12.329269
# 3 2017-07-23     12.121754   12.222322      12.329275  12.222615  12.331567
# 4 2017-07-30     12.077165   12.177895      12.287542  12.218419  12.322874
#
#     trend_95  seasonality_5  seasonality  seasonality_95  regression_5  \
# 0  12.435567       0.023342     0.054511        0.076124      0.004599
# 1  12.444151       0.146387     0.179109        0.204080      0.007272
# 2  12.441898      -0.000433     0.031216        0.051681      0.006270
# 3  12.453743      -0.143769    -0.112244       -0.092680      0.004225
# 4  12.428633      -0.184385    -0.154620       -0.132869      0.004059
#
#    regression  regression_95
# 0    0.026254       0.039776
# 1    0.014737       0.022364
# 2    0.016838       0.024393
# 3    0.010565       0.017122
# 4    0.011917       0.020557

# %% [markdown]
# #### 2.3.1 Pyfunc flavor

# %%
loaded_pyfunc.predict(test_df).head()
# Out:
#         week  prediction_5  prediction  prediction_95    trend_5      trend  \
# 0 2017-07-02     12.329969   12.415831      12.505553  12.249114  12.337002
# 1 2017-07-09     12.426513   12.534631      12.623807  12.234586  12.345293
# 2 2017-07-16     12.299631   12.376752      12.470228  12.246894  12.329269
# 3 2017-07-23     12.121754   12.222322      12.329275  12.222615  12.331567
# 4 2017-07-30     12.077165   12.177895      12.287542  12.218419  12.322874
#
#     trend_95  seasonality_5  seasonality  seasonality_95  regression_5  \
# 0  12.435567       0.023342     0.054511        0.076124      0.004599
# 1  12.444151       0.146387     0.179109        0.204080      0.007272
# 2  12.441898      -0.000433     0.031216        0.051681      0.006270
# 3  12.453743      -0.143769    -0.112244       -0.092680      0.004225
# 4  12.428633      -0.184385    -0.154620       -0.132869      0.004059
#
#    regression  regression_95
# 0    0.026254       0.039776
# 1    0.014737       0.022364
# 2    0.016838       0.024393
# 3    0.010565       0.017122
# 4    0.011917       0.020557

# %% [markdown]
# ## 3. Model deployment example
# ### 3.1 Create experiment

# %%
mlflow.set_experiment("Test Orbit")

with mlflow.start_run() as run:

    dlt = DLT(
        response_col="claims",
        date_col="week",
        regressor_col=["trend.unemploy", "trend.filling", "trend.job"],
        seasonality=52,
    )
    dlt.fit(df=train_df)
    dlt.pyfunc_predict_conf = pyfunc_predict_conf
    
    # Need to include a model signature, so MLflow can automatically decode datetime from JSON
    prediction = dlt.predict(test_df)
    signature = infer_signature(test_df, prediction)

    mlflow_flavors.orbit.log_model(
        orbit_model=dlt, 
        artifact_path=model_path, 
        signature=signature
    )

run_id = run.info.run_id
print(f"MLflow run id: {run_id}")
# Out:
# INFO:orbit:Sampling (PyStan) with chains: 4, cores: 8, temperature: 1.000, warmups (per chain): 225 and samples(per chain): 25.
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# 2023/01/06 13:57:37 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmphq_yud6b/model/model.pkl, flavor: orbit), fall back to return ['orbit==1.1.3']. Set logging level to DEBUG to see the full traceback.
# MLflow run id: 772cb6959e8c42a0844e90eceee3082c

# %% [markdown]
# ### 3.2 Deploy pyfunc model to local REST API endpoint
# - Open a terminal window and cd into `examples` directory
# - In the terminal run: `mlflow models serve -m runs:/<run_id>/model --env-manager local --host <host>`
#   - where you substitute `<run_id>` by the above run id and ` <host>` by the network address to listen on (e.g. 127.0.0.1)
# - More details here: https://www.mlflow.org/docs/latest/cli.html#mlflow-models-serve

# %% [markdown]
# ### 3.3 Request predictions from local REST API endpoint
# - For mor details see: https://www.mlflow.org/docs/latest/models.html#built-in-deployment-tools

# %% [markdown]
#  #### 3.3.1 JSON input using `dataframe_split` field with pandas DataFrame in the `split` orientation

# %%
host = "127.0.0.1"
url = f"http://{host}:5000/invocations"

# Transform datetime column according to: https://mlflow.org/docs/latest/models.html#encoding-complex-data
test_df_serializable = test_df.copy()
test_df_serializable["week"] = test_df_serializable["week"].dt.strftime('%Y-%m-%dT%H:%M:%SZ')
json_data = {"dataframe_split": test_df_serializable.to_dict(orient="split")}
print(json_data)

# # Un-comment the below lines to run the prediction request
# import requests
# response = requests.post(url, json=json_data)
# response.json()
# Out:
# {'predictions': [{'week': '2017-07-02T00:00:00',
#    'prediction_5': 12.32996933073647,
#    'prediction': 12.415831378619774,
#    'prediction_95': 12.505552893905719,
#    'trend_5': 12.249114289984634,
#    'trend': 12.337001774122264,
#    'trend_95': 12.435566905984784,
#    'seasonality_5': 0.023341526857371835,
#    'seasonality': 0.054510641952702846,
#    'seasonality_95': 0.07612376663154719,
#    'regression_5': 0.004599459909616243,
#    'regression': 0.026254486599328643,
#    'regression_95': 0.0397756624111687},
#   {'week': '2017-07-09T00:00:00',
#    'prediction_5': 12.426513169782348,
#    'prediction': 12.534630671657983,
#    'prediction_95': 12.623806508419108,
#    'trend_5': 12.234585677032554,
#    'trend': 12.34529267295582,
#    'trend_95': 12.444150957640982,
#    'seasonality_5': 0.14638690846722338,
#    'seasonality': 0.1791088377692887,
#    'seasonality_95': 0.204080045567357,
#    'regression_5': 0.007271859206126872,
#    'regression': 0.014737131377118406,
#    'regression_95': 0.022364045206419186},
#   {'week': '2017-07-16T00:00:00',
#    'prediction_5': 12.299630850888889,
#    'prediction': 12.376751649204952,
#    'prediction_95': 12.47022834182063,
#    'trend_5': 12.246893953767092,
#    'trend': 12.329269147298962,
#    'trend_95': 12.441898247456294,
#    'seasonality_5': -0.0004330028873194169,
#    'seasonality': 0.031215562182612937,
#    'seasonality_95': 0.05168065660123865,
#    'regression_5': 0.006270372594169444,
#    'regression': 0.016838255719160748,
#    'regression_95': 0.024392582792499062},
#   {'week': '2017-07-23T00:00:00',
#    'prediction_5': 12.12175364435404,
#    'prediction': 12.222322109904905,
#    'prediction_95': 12.329274544086857,
#    'trend_5': 12.222614753115543,
#    'trend': 12.331567400047055,
#    'trend_95': 12.453743401061109,
#    'seasonality_5': -0.14376946828036843,
#    'seasonality': -0.11224384250431918,
#    'seasonality_95': -0.09268001396316627,
#    'regression_5': 0.004224753675223832,
#    'regression': 0.010565054671679674,
#    'regression_95': 0.0171220296807572},
#   {'week': '2017-07-30T00:00:00',
#    'prediction_5': 12.077164913589325,
#    'prediction': 12.177894707201737,
#    'prediction_95': 12.287542431645981,
#    'trend_5': 12.218419424444377,
#    'trend': 12.322874016219554,
#    'trend_95': 12.428632665666102,
#    'seasonality_5': -0.18438466214820734,
#    'seasonality': -0.15462039610206224,
#    'seasonality_95': -0.1328692224674293,
#    'regression_5': 0.004059252186196809,
#    'regression': 0.011917348815715384,
#    'regression_95': 0.020556528232925156},
#   {'week': '2017-08-06T00:00:00',
#    'prediction_5': 12.168589618371167,
#    'prediction': 12.248918131499149,
#    'prediction_95': 12.320088206913027,
#    'trend_5': 12.232715076185368,
#    'trend': 12.327664551443668,
#    'trend_95': 12.41115318113533,
#    'seasonality_5': -0.12087853516846214,
#    'seasonality': -0.09216134844156597,
#    'seasonality_95': -0.06832056067766402,
#    'regression_5': 0.0027797852990165354,
#    'regression': 0.010671295909586893,
#    'regression_95': 0.01988156123449008},
#   {'week': '2017-08-13T00:00:00',
#    'prediction_5': 12.088471476124761,
#    'prediction': 12.18602592202534,
#    'prediction_95': 12.29022079915503,
#    'trend_5': 12.23189985551317,
#    'trend': 12.330090751699608,
#    'trend_95': 12.43669987191582,
#    'seasonality_5': -0.17500119000169506,
#    'seasonality': -0.14538031997691855,
#    'seasonality_95': -0.12276741869875135,
#    'regression_5': -0.002517834232836677,
#    'regression': 0.0018815903582190823,
#    'regression_95': 0.006310541125840315},
#   {'week': '2017-08-20T00:00:00',
#    'prediction_5': 12.047702075569244,
#    'prediction': 12.168047807141846,
#    'prediction_95': 12.25858638084704,
#    'trend_5': 12.192675468585596,
#    'trend': 12.3166034988066,
#    'trend_95': 12.427957458201364,
#    'seasonality_5': -0.18267647727791636,
#    'seasonality': -0.1520392865509473,
#    'seasonality_95': -0.13074852483429847,
#    'regression_5': -0.0018763558260434245,
#    'regression': -2.752450490240094e-05,
#    'regression_95': 0.002065277361344145},
#   {'week': '2017-08-27T00:00:00',
#    'prediction_5': 12.073519315406456,
#    'prediction': 12.173407008316245,
#    'prediction_95': 12.263547415023641,
#    'trend_5': 12.230349766590809,
#    'trend': 12.321204761832842,
#    'trend_95': 12.424423290322792,
#    'seasonality_5': -0.18066633839863072,
#    'seasonality': -0.15054019146486386,
#    'seasonality_95': -0.12839679930563688,
#    'regression_5': -0.0017052215664495381,
#    'regression': 0.0037271874244229905,
#    'regression_95': 0.009517495205294697},
#   {'week': '2017-09-03T00:00:00',
#    'prediction_5': 12.08333114945346,
#    'prediction': 12.182024389285942,
#    'prediction_95': 12.279515022117499,
#    'trend_5': 12.20195236811007,
#    'trend': 12.314864712540672,
#    'trend_95': 12.417760954885503,
#    'seasonality_5': -0.17752205787043976,
#    'seasonality': -0.1468762319732329,
#    'seasonality_95': -0.12298093090235358,
#    'regression_5': 0.0015283293070445828,
#    'regression': 0.012425754683710266,
#    'regression_95': 0.01854624081977626},
#   {'week': '2017-09-10T00:00:00',
#    'prediction_5': 11.944621303742945,
#    'prediction': 12.05164091755795,
#    'prediction_95': 12.15296904588768,
#    'trend_5': 12.202469287761483,
#    'trend': 12.307986689637621,
#    'trend_95': 12.408464784879715,
#    'seasonality_5': -0.29004183619451984,
#    'seasonality': -0.25784071248087626,
#    'seasonality_95': -0.23393595485710586,
#    'regression_5': -0.00083263660724228,
#    'regression': 0.0019043469527008942,
#    'regression_95': 0.004372176271625357},
#   {'week': '2017-09-17T00:00:00',
#    'prediction_5': 12.025568647462162,
#    'prediction': 12.129147409520415,
#    'prediction_95': 12.216458105925332,
#    'trend_5': 12.205214990183636,
#    'trend': 12.315595970019157,
#    'trend_95': 12.403267499800734,
#    'seasonality_5': -0.22558762609041935,
#    'seasonality': -0.19542452289195755,
#    'seasonality_95': -0.1738148265257605,
#    'regression_5': 0.0037036910119500567,
#    'regression': 0.008880899951764026,
#    'regression_95': 0.013475984942786252},
#   {'week': '2017-09-24T00:00:00',
#    'prediction_5': 11.9990251347045,
#    'prediction': 12.100202656250783,
#    'prediction_95': 12.1797917062156,
#    'trend_5': 12.194303835062037,
#    'trend': 12.312283723303814,
#    'trend_95': 12.430310058856048,
#    'seasonality_5': -0.25823879147769335,
#    'seasonality': -0.22819200582036936,
#    'seasonality_95': -0.20678021896053433,
#    'regression_5': 0.003453492285213294,
#    'regression': 0.010588864604281439,
#    'regression_95': 0.015566206287548437},
#   {'week': '2017-10-01T00:00:00',
#    'prediction_5': 12.020073640948512,
#    'prediction': 12.124877034994892,
#    'prediction_95': 12.23865033968509,
#    'trend_5': 12.194437510725473,
#    'trend': 12.306210251535392,
#    'trend_95': 12.41972382248405,
#    'seasonality_5': -0.22994086234186106,
#    'seasonality': -0.19444886460425087,
#    'seasonality_95': -0.1697086971712548,
#    'regression_5': 0.0028992812246920806,
#    'regression': 0.010874606736131939,
#    'regression_95': 0.015855912577063265},
#   {'week': '2017-10-08T00:00:00',
#    'prediction_5': 12.179839462202303,
#    'prediction': 12.275870141082617,
#    'prediction_95': 12.38485224090129,
#    'trend_5': 12.205011663075835,
#    'trend': 12.316064495918226,
#    'trend_95': 12.41745230090733,
#    'seasonality_5': -0.07595262778377442,
#    'seasonality': -0.04188777450661263,
#    'seasonality_95': -0.0216932164695688,
#    'regression_5': 0.0035877360560045385,
#    'regression': 0.012913986051589589,
#    'regression_95': 0.021183446460016627},
#   {'week': '2017-10-15T00:00:00',
#    'prediction_5': 12.12852882331064,
#    'prediction': 12.237618253311101,
#    'prediction_95': 12.327358018070433,
#    'trend_5': 12.181811223781944,
#    'trend': 12.297621554681102,
#    'trend_95': 12.39894365800313,
#    'seasonality_5': -0.10788422870466824,
#    'seasonality': -0.07765695726107638,
#    'seasonality_95': -0.05961995991173428,
#    'regression_5': 0.00457391352310951,
#    'regression': 0.017885497507713143,
#    'regression_95': 0.026403247596798986},
#   {'week': '2017-10-22T00:00:00',
#    'prediction_5': 12.166713864702489,
#    'prediction': 12.268483961992974,
#    'prediction_95': 12.339341589240238,
#    'trend_5': 12.190868574255104,
#    'trend': 12.295649941662376,
#    'trend_95': 12.375298516906255,
#    'seasonality_5': -0.08082982995383063,
#    'seasonality': -0.0475786148899674,
#    'seasonality_95': -0.027747525212304783,
#    'regression_5': 0.00459360000805786,
#    'regression': 0.01650472706754684,
#    'regression_95': 0.024307484348559484},
#   {'week': '2017-10-29T00:00:00',
#    'prediction_5': 12.178360636896276,
#    'prediction': 12.311792633048162,
#    'prediction_95': 12.43374684984356,
#    'trend_5': 12.167889448580395,
#    'trend': 12.299343160636841,
#    'trend_95': 12.415499731049508,
#    'seasonality_5': -0.04340103846965292,
#    'seasonality': -0.010192020962898816,
#    'seasonality_95': 0.010576979733958283,
#    'regression_5': 0.0037366111638041425,
#    'regression': 0.01853330398863077,
#    'regression_95': 0.02815227819891771},
#   {'week': '2017-11-05T00:00:00',
#    'prediction_5': 12.240528080051329,
#    'prediction': 12.374427231826719,
#    'prediction_95': 12.498889613557639,
#    'trend_5': 12.177058386845983,
#    'trend': 12.295706018999034,
#    'trend_95': 12.410835895444311,
#    'seasonality_5': 0.030116805454542355,
#    'seasonality': 0.06339606683497809,
#    'seasonality_95': 0.08639372161376459,
#    'regression_5': 0.002718108148539095,
#    'regression': 0.015377599097640363,
#    'regression_95': 0.02273862047623743},
#   {'week': '2017-11-12T00:00:00',
#    'prediction_5': 12.167467333949833,
#    'prediction': 12.257747919314312,
#    'prediction_95': 12.34319314080469,
#    'trend_5': 12.212761152576915,
#    'trend': 12.305595479009753,
#    'trend_95': 12.395128299302401,
#    'seasonality_5': -0.11535772429426042,
#    'seasonality': -0.07697082219475507,
#    'seasonality_95': -0.048471749659036265,
#    'regression_5': 0.008003364441288673,
#    'regression': 0.03274616669207482,
#    'regression_95': 0.051540378499080386},
#   {'week': '2017-11-19T00:00:00',
#    'prediction_5': 12.374177520139385,
#    'prediction': 12.472829804518312,
#    'prediction_95': 12.57976629870614,
#    'trend_5': 12.200634309307887,
#    'trend': 12.297502587984125,
#    'trend_95': 12.401260343495698,
#    'seasonality_5': 0.054997578091411474,
#    'seasonality': 0.09826320815916936,
#    'seasonality_95': 0.17265292008626568,
#    'regression_5': 0.0003302881218418867,
#    'regression': 0.0784509750948702,
#    'regression_95': 0.11633013485698365},
#   {'week': '2017-11-26T00:00:00',
#    'prediction_5': 12.23724956590355,
#    'prediction': 12.326682613623921,
#    'prediction_95': 12.451771203018284,
#    'trend_5': 12.192484720954695,
#    'trend': 12.298857043976426,
#    'trend_95': 12.404636627866905,
#    'seasonality_5': -0.006633137418848564,
#    'seasonality': 0.028991296226024865,
#    'seasonality_95': 0.05328104424400445,
#    'regression_5': 0.0022516954471731953,
#    'regression': 0.007631079504819673,
#    'regression_95': 0.014716732619249702},
#   {'week': '2017-12-03T00:00:00',
#    'prediction_5': 12.552748922325234,
#    'prediction': 12.658283981666699,
#    'prediction_95': 12.749312903139671,
#    'trend_5': 12.175575513562794,
#    'trend': 12.279808462343048,
#    'trend_95': 12.355743111400098,
#    'seasonality_5': 0.3365500821684241,
#    'seasonality': 0.3696283933634936,
#    'seasonality_95': 0.39006811696136695,
#    'regression_5': 0.008207648073359278,
#    'regression': 0.01809751667681328,
#    'regression_95': 0.02720693898553187},
#   {'week': '2017-12-10T00:00:00',
#    'prediction_5': 12.386411308154665,
#    'prediction': 12.515199388648874,
#    'prediction_95': 12.599817923056461,
#    'trend_5': 12.16061571147553,
#    'trend': 12.287372566547585,
#    'trend_95': 12.383153295046812,
#    'seasonality_5': 0.17255941739436603,
#    'seasonality': 0.20368527387801094,
#    'seasonality_95': 0.23205127223452593,
#    'regression_5': 0.004204651128272479,
#    'regression': 0.030880816260000395,
#    'regression_95': 0.04546451183957626},
#   {'week': '2017-12-17T00:00:00',
#    'prediction_5': 12.458248521581469,
#    'prediction': 12.531249209988474,
#    'prediction_95': 12.61607062698291,
#    'trend_5': 12.194022114033684,
#    'trend': 12.275671663781072,
#    'trend_95': 12.373622139011806,
#    'seasonality_5': 0.16777977997192153,
#    'seasonality': 0.2046843499538769,
#    'seasonality_95': 0.25790168139758746,
#    'regression_5': 0.005965745312780432,
#    'regression': 0.05373714165453093,
#    'regression_95': 0.07709468677762545},
#   {'week': '2017-12-24T00:00:00',
#    'prediction_5': 12.569340429983964,
#    'prediction': 12.654572128266105,
#    'prediction_95': 12.760939020881358,
#    'trend_5': 12.178903225101438,
#    'trend': 12.282267441960677,
#    'trend_95': 12.398012034891638,
#    'seasonality_5': 0.27353301059172785,
#    'seasonality': 0.3158463527161597,
#    'seasonality_95': 0.35376195981410036,
#    'regression_5': -0.0023807760645357095,
#    'regression': 0.05941880583997881,
#    'regression_95': 0.09573565942721071},
#   {'week': '2017-12-31T00:00:00',
#    'prediction_5': 12.606968268199081,
#    'prediction': 12.693592590125565,
#    'prediction_95': 12.803313897078628,
#    'trend_5': 12.191351419543834,
#    'trend': 12.280664275015457,
#    'trend_95': 12.396285836446559,
#    'seasonality_5': 0.3444923554211511,
#    'seasonality': 0.37753995058328915,
#    'seasonality_95': 0.4041093054428992,
#    'regression_5': 0.013988334358151508,
#    'regression': 0.036951113574421456,
#    'regression_95': 0.055234789839031226},
#   {'week': '2018-01-07T00:00:00',
#    'prediction_5': 12.80636635344849,
#    'prediction': 12.87865412243659,
#    'prediction_95': 12.973256421718052,
#    'trend_5': 12.20313885468196,
#    'trend': 12.28619124861898,
#    'trend_95': 12.377630069701363,
#    'seasonality_5': 0.5259764626186963,
#    'seasonality': 0.5638264722385502,
#    'seasonality_95': 0.5910657078279845,
#    'regression_5': 0.015473654510468308,
#    'regression': 0.030720188981221648,
#    'regression_95': 0.044851671642928345},
#   {'week': '2018-01-14T00:00:00',
#    'prediction_5': 12.564973236247678,
#    'prediction': 12.659489834033309,
#    'prediction_95': 12.763136172182762,
#    'trend_5': 12.173822962328636,
#    'trend': 12.270103705256432,
#    'trend_95': 12.402101883747937,
#    'seasonality_5': 0.3281201435700037,
#    'seasonality': 0.36215874122519254,
#    'seasonality_95': 0.3855988342152384,
#    'regression_5': 0.013606994256678434,
#    'regression': 0.026723283467380003,
#    'regression_95': 0.03979697067647712},
#   {'week': '2018-01-21T00:00:00',
#    'prediction_5': 12.32075249717578,
#    'prediction': 12.44687603273725,
#    'prediction_95': 12.533527993149448,
#    'trend_5': 12.15705365340017,
#    'trend': 12.275527432423116,
#    'trend_95': 12.373430271966408,
#    'seasonality_5': 0.10296957369609588,
#    'seasonality': 0.1396143399225268,
#    'seasonality_95': 0.1623070021028968,
#    'regression_5': 0.016078317681649832,
#    'regression': 0.035734483827455116,
#    'regression_95': 0.052957916039679344},
#   {'week': '2018-01-28T00:00:00',
#    'prediction_5': 12.363325344877683,
#    'prediction': 12.45412640593794,
#    'prediction_95': 12.60180974693965,
#    'trend_5': 12.187331609997257,
#    'trend': 12.273679728632914,
#    'trend_95': 12.427162765014971,
#    'seasonality_5': 0.11069000454843217,
#    'seasonality': 0.14618653645394425,
#    'seasonality_95': 0.17035895623387315,
#    'regression_5': 0.01612642318377323,
#    'regression': 0.0349420153263713,
#    'regression_95': 0.05055504963620029},
#   {'week': '2018-02-04T00:00:00',
#    'prediction_5': 12.273802568855995,
#    'prediction': 12.370696893036895,
#    'prediction_95': 12.490791513395179,
#    'trend_5': 12.170164717999626,
#    'trend': 12.27392673743403,
#    'trend_95': 12.397407420393545,
#    'seasonality_5': 0.053109674598662775,
#    'seasonality': 0.08432949866677839,
#    'seasonality_95': 0.10860373263756438,
#    'regression_5': 0.010133404421253255,
#    'regression': 0.021945445667130938,
#    'regression_95': 0.031388128064510704},
#   {'week': '2018-02-11T00:00:00',
#    'prediction_5': 12.212093489696942,
#    'prediction': 12.299087481503562,
#    'prediction_95': 12.419367651490786,
#    'trend_5': 12.17912988547827,
#    'trend': 12.26250295614295,
#    'trend_95': 12.397386889858554,
#    'seasonality_5': -0.016944569341870063,
#    'seasonality': 0.013868682564521409,
#    'seasonality_95': 0.03441244697540717,
#    'regression_5': 0.0076288385958472385,
#    'regression': 0.026402773972257203,
#    'regression_95': 0.038672138001533574},
#   {'week': '2018-02-18T00:00:00',
#    'prediction_5': 12.17122483506836,
#    'prediction': 12.276447563568096,
#    'prediction_95': 12.40074652684365,
#    'trend_5': 12.153472611055845,
#    'trend': 12.260616170535101,
#    'trend_95': 12.389833977291179,
#    'seasonality_5': -0.039361114006116596,
#    'seasonality': -0.008426508661960867,
#    'seasonality_95': 0.014412414104997275,
#    'regression_5': 0.007480697177981372,
#    'regression': 0.019103348102609594,
#    'regression_95': 0.02887800381475286},
#   {'week': '2018-02-25T00:00:00',
#    'prediction_5': 12.097466714547961,
#    'prediction': 12.198860726650043,
#    'prediction_95': 12.329442128434454,
#    'trend_5': 12.16358335162234,
#    'trend': 12.26026650329953,
#    'trend_95': 12.392350268670132,
#    'seasonality_5': -0.10801556021917186,
#    'seasonality': -0.0713037164099628,
#    'seasonality_95': -0.03941428946842204,
#    'regression_5': 0.007175454861518525,
#    'regression': 0.014508236131572478,
#    'regression_95': 0.02122786765123769},
#   {'week': '2018-03-04T00:00:00',
#    'prediction_5': 12.19585490640588,
#    'prediction': 12.297771284749006,
#    'prediction_95': 12.416586199058651,
#    'trend_5': 12.170374119394813,
#    'trend': 12.2656215682509,
#    'trend_95': 12.376022649986895,
#    'seasonality_5': -0.016321666172137712,
#    'seasonality': 0.015367497994514919,
#    'seasonality_95': 0.036843842567026816,
#    'regression_5': 0.0056151745058666425,
#    'regression': 0.014113436077066235,
#    'regression_95': 0.022676435133669976},
#   {'week': '2018-03-11T00:00:00',
#    'prediction_5': 12.111016188435705,
#    'prediction': 12.20636690269269,
#    'prediction_95': 12.311565976424047,
#    'trend_5': 12.158734117465801,
#    'trend': 12.26086026211322,
#    'trend_95': 12.376579770620806,
#    'seasonality_5': -0.10086216132338927,
#    'seasonality': -0.07113600627304822,
#    'seasonality_95': -0.05034040916312004,
#    'regression_5': 0.00457391352310951,
#    'regression': 0.017885497507713143,
#    'regression_95': 0.026403247596798986},
#   {'week': '2018-03-18T00:00:00',
#    'prediction_5': 12.099989629291862,
#    'prediction': 12.2075745465802,
#    'prediction_95': 12.317178868134098,
#    'trend_5': 12.148523778282794,
#    'trend': 12.259661208771618,
#    'trend_95': 12.388916288958356,
#    'seasonality_5': -0.0959195065052694,
#    'seasonality': -0.0667729320730788,
#    'seasonality_95': -0.045650942746061914,
#    'regression_5': 0.004790384967166669,
#    'regression': 0.015334685733406211,
#    'regression_95': 0.025545437976942337},
#   {'week': '2018-03-25T00:00:00',
#    'prediction_5': 12.14162011802617,
#    'prediction': 12.229709547254544,
#    'prediction_95': 12.361502837257532,
#    'trend_5': 12.162272119467588,
#    'trend': 12.264159550508076,
#    'trend_95': 12.381068642404053,
#    'seasonality_5': -0.0822939410016677,
#    'seasonality': -0.051510417284040405,
#    'seasonality_95': -0.02981866326151016,
#    'regression_5': 0.007763926524417955,
#    'regression': 0.029502630143211334,
#    'regression_95': 0.047773477176834},
#   {'week': '2018-04-01T00:00:00',
#    'prediction_5': 12.052203258308928,
#    'prediction': 12.153100062683926,
#    'prediction_95': 12.232661505076777,
#    'trend_5': 12.136024101797585,
#    'trend': 12.244840629787188,
#    'trend_95': 12.353609366828609,
#    'seasonality_5': -0.14215422187930252,
#    'seasonality': -0.10716970397203535,
#    'seasonality_95': -0.08011374735549341,
#    'regression_5': 0.005664183689055466,
#    'regression': 0.016567853118295055,
#    'regression_95': 0.025795369956625142},
#   {'week': '2018-04-08T00:00:00',
#    'prediction_5': 12.173468276247768,
#    'prediction': 12.280881196964074,
#    'prediction_95': 12.377747569629154,
#    'trend_5': 12.14466505596522,
#    'trend': 12.252279988392996,
#    'trend_95': 12.351942097242068,
#    'seasonality_5': -0.014050713165649095,
#    'seasonality': 0.020937472519166413,
#    'seasonality_95': 0.04571685139871754,
#    'regression_5': 0.0063063725096323955,
#    'regression': 0.013424872798474041,
#    'regression_95': 0.019444068222644682},
#   {'week': '2018-04-15T00:00:00',
#    'prediction_5': 12.137352159411538,
#    'prediction': 12.228008714020916,
#    'prediction_95': 12.324163563705655,
#    'trend_5': 12.160409452401552,
#    'trend': 12.247345883916362,
#    'trend_95': 12.358635271575787,
#    'seasonality_5': -0.06738823113596655,
#    'seasonality': -0.037631725659975475,
#    'seasonality_95': -0.011933739424589368,
#    'regression_5': 0.006426536668404693,
#    'regression': 0.016259564175290855,
#    'regression_95': 0.024580792237235853},
#   {'week': '2018-04-22T00:00:00',
#    'prediction_5': 12.159966255064301,
#    'prediction': 12.259235763606512,
#    'prediction_95': 12.382400065742894,
#    'trend_5': 12.141364453253045,
#    'trend': 12.241529708751445,
#    'trend_95': 12.356037158473285,
#    'seasonality_5': -0.018884271740210814,
#    'seasonality': 0.014538929350724383,
#    'seasonality_95': 0.0383701464037655,
#    'regression_5': 0.0033758287020259348,
#    'regression': 0.006991405214920374,
#    'regression_95': 0.011027087819933192},
#   {'week': '2018-04-29T00:00:00',
#    'prediction_5': 12.057852599435734,
#    'prediction': 12.161491885463338,
#    'prediction_95': 12.247784967915955,
#    'trend_5': 12.135799551876408,
#    'trend': 12.253027628915174,
#    'trend_95': 12.347196715236425,
#    'seasonality_5': -0.1233842798901557,
#    'seasonality': -0.08977335367712751,
#    'seasonality_95': -0.06587102287193612,
#    'regression_5': 0.0016697186899575426,
#    'regression': 0.005746094586724929,
#    'regression_95': 0.009540351915331936},
#   {'week': '2018-05-06T00:00:00',
#    'prediction_5': 12.117244992463291,
#    'prediction': 12.191228825766872,
#    'prediction_95': 12.295318507771672,
#    'trend_5': 12.148730092595356,
#    'trend': 12.24478963103375,
#    'trend_95': 12.344066382302328,
#    'seasonality_5': -0.09216339937338082,
#    'seasonality': -0.05670790474754862,
#    'seasonality_95': -0.03011884565968112,
#    'regression_5': 0.00307193878258203,
#    'regression': 0.011814413614169864,
#    'regression_95': 0.019741734943305417},
#   {'week': '2018-05-13T00:00:00',
#    'prediction_5': 12.04551653839404,
#    'prediction': 12.151926591333776,
#    'prediction_95': 12.256050565327941,
#    'trend_5': 12.139232649707969,
#    'trend': 12.241103229629875,
#    'trend_95': 12.350520070046771,
#    'seasonality_5': -0.12795660360838407,
#    'seasonality': -0.09202779938331994,
#    'seasonality_95': -0.0649887433131533,
#    'regression_5': 0.0005180128284189628,
#    'regression': 0.002844580486163533,
#    'regression_95': 0.0049839604550503906},
#   {'week': '2018-05-20T00:00:00',
#    'prediction_5': 12.046958300804386,
#    'prediction': 12.153383271619688,
#    'prediction_95': 12.269284970515992,
#    'trend_5': 12.112177186248429,
#    'trend': 12.232726999672042,
#    'trend_95': 12.363888137811609,
#    'seasonality_5': -0.11431771811434079,
#    'seasonality': -0.08077202005429579,
#    'seasonality_95': -0.056238208378968556,
#    'regression_5': -0.0034399042338374734,
#    'regression': 0.0028815570389938193,
#    'regression_95': 0.008652561601724847},
#   {'week': '2018-05-27T00:00:00',
#    'prediction_5': 12.137393477628233,
#    'prediction': 12.227486484741167,
#    'prediction_95': 12.33509670801467,
#    'trend_5': 12.13571361232717,
#    'trend': 12.247034600268753,
#    'trend_95': 12.363165338765894,
#    'seasonality_5': -0.04718678071363567,
#    'seasonality': -0.016343878900437203,
#    'seasonality_95': 0.00970778338807844,
#    'regression_5': -0.0020290124747790877,
#    'regression': 0.0030173524571803258,
#    'regression_95': 0.008403828463065184},
#   {'week': '2018-06-03T00:00:00',
#    'prediction_5': 12.048501007708763,
#    'prediction': 12.165494736337633,
#    'prediction_95': 12.28228727508872,
#    'trend_5': 12.105265411737086,
#    'trend': 12.241639740104125,
#    'trend_95': 12.357666822421976,
#    'seasonality_5': -0.10951404690405865,
#    'seasonality': -0.07479172468428039,
#    'seasonality_95': -0.04933206488248988,
#    'regression_5': 0.0007415222741114087,
#    'regression': 0.005324138916717866,
#    'regression_95': 0.011778985634339626},
#   {'week': '2018-06-10T00:00:00',
#    'prediction_5': 12.190431034302344,
#    'prediction': 12.269516386341618,
#    'prediction_95': 12.372064818381793,
#    'trend_5': 12.153607384258013,
#    'trend': 12.238321829644793,
#    'trend_95': 12.328671610667508,
#    'seasonality_5': -0.012995221873622977,
#    'seasonality': 0.017533268891553606,
#    'seasonality_95': 0.0442793139899503,
#    'regression_5': 0.002757562035268453,
#    'regression': 0.013358327833313668,
#    'regression_95': 0.025627407246823393},
#   {'week': '2018-06-17T00:00:00',
#    'prediction_5': 12.131561804859864,
#    'prediction': 12.222710149027824,
#    'prediction_95': 12.34856401948738,
#    'trend_5': 12.115168523815962,
#    'trend': 12.221631210076913,
#    'trend_95': 12.341977312501307,
#    'seasonality_5': -0.04104052763590319,
#    'seasonality': -0.009331857537921765,
#    'seasonality_95': 0.017327837064302992,
#    'regression_5': 0.002686170250353976,
#    'regression': 0.013449860480103847,
#    'regression_95': 0.02348825302338778},
#   {'week': '2018-06-24T00:00:00',
#    'prediction_5': 12.143722637656241,
#    'prediction': 12.273869064428151,
#    'prediction_95': 12.415189907965129,
#    'trend_5': 12.09744847751161,
#    'trend': 12.22819472252738,
#    'trend_95': 12.369215364281892,
#    'seasonality_5': -0.001259977859128096,
#    'seasonality': 0.0317045117127806,
#    'seasonality_95': 0.05789533159359237,
#    'regression_5': 0.004558004384455124,
#    'regression': 0.014165807263880167,
#    'regression_95': 0.025056859419483365}]}
